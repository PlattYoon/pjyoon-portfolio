# %% [markdown]
# # IDA demo — watch it notice, unprompted
#
# 1. Pick the `.venv` kernel (top-right) if asked.
# 2. Run the code cell below **3–4 times** — it fails every time on purpose.
# 3. After a couple of failed runs, within ~30s IDA pops an inline message offering help. You never asked it to.
#
# IDA is already switched on for this window (see `.vscode/settings.json`).

# %%
# This keeps failing on purpose. Run it a few times.
print("total_price")

for i in range(5):
    print(price)
# Out:
# total_price
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # This keeps failing on purpose. Run it a few times.
#       2 print("total_price")
#       3
#       4 for i in range(5):
# ----> 5     print(price)
#
# NameError: name 'price' is not defined
